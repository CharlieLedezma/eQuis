# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import sympy as smp
from matplotlib import animation
from matplotlib.animation import PillowWriter
from IPython.display import Image
from sympy.physics.mechanics import dynamicsymbols, init_vprinting
import math

# %%
init_vprinting()

# %%
#Image('Exe07_TwoLinkPlanarMarghitu.jpg')

# %%
t, m, m_1, m_2, I_A, I_C1, L_1, L_2, l, g = smp.symbols('t, m, m_1, m_2, I_A, I_C1, L_1, L_2, l, g')
beta_01, beta_12,gamma_01, gamma_12 = smp.symbols ('beta_01 beta_12 gamma_01 gamma_12')
omega_1, omega_2 = smp.symbols ('omega_1 omega_2')

# %%
beta_01 = 450   #Nms/rad
beta_12 = 200   #Nms/rad
gamma_01 = 300  #Nm/rad
gamma_12 = 300  #Nm/rad
q1f = smp.Rational(1,6)*math.pi
q2f = smp.Rational(1,3)*math.pi

# %% [markdown]
# Generalized Coordinates

# %%
#theta_1 = smp.Symbol('theta_1')
#theta_2 = smp.Symbol('theta_2')
theta_1, theta_2 = smp.symbols(r'\theta_1 \theta_2', cls=smp.Function)

# %% [markdown]
# Define $\theta(t)$ and $\dot{\theta}(t)$ and $\ddot{\theta}(t)$

# %%
theta_1 = theta_1(t)
theta_2 = theta_2(t)
theta_1d = smp.diff(theta_1,t)
theta_2d = smp.diff(theta_2,t)
theta_1dd = smp.diff(theta_1d,t)
theta_2dd = smp.diff(theta_2d,t)

# %%
theta_1, theta_2, theta_1d, theta_2d, theta_1dd, theta_2dd
# Out:
# (\theta₁, \theta₂, \thėta₁, \thėta₂, \thëta₁, \thëta₂)

# %% [markdown]
# I. Direct Dynamics

# %%
#Feedback control laws are given
L_1 = l ; L_2 = l

# %%
c1 = smp.cos(theta_1)
c2 = smp.cos(theta_2)
s1 = smp.sin(theta_1)
s2 = smp.sin(theta_2)
xB = L_1*c1; yB = L_1*s1
rB = smp.Matrix([[xB, yB, 0]])
rC1 = rB/2; vC1 = smp.diff(rC1,t)
xD = xB + L_2*c2; yD = yB + L_2*s2; 
rD = smp.Matrix([[xD, yD, 0]])
rC2 = (rB + rD)/2; vC2 = smp.diff(rC2,t)
omega_1 = smp.Matrix([[0, 0, theta_1d]])
omega_2 = smp.Matrix([[0, 0, theta_2d]])
m_1 = m ; m_2 = m

# %% [markdown]
# Define both kinetic and potential energy:
#
# * Kinetic energy $T$ comes from the motion of the two arms

# %%
I_A = smp.Rational(1,3)*m_1*L_1**2
I_C1 = smp.Rational(1,12)*m_2*L_2**2

T1 = smp.Rational(1/2)*I_A*omega_1.dot(omega_1)
T2 = smp.Rational(1/2)*I_C1*theta_2d**2 + smp.Rational(1/2)*m_2*vC2.dot(vC2) 
T = smp.simplify(T1 + T2)
T
# Out:
#  2   ⎛                                                    2          2⎞
# l ⋅m⋅⎝3⋅cos(\theta₁ - \theta₂)⋅\thėta₁⋅\thėta₂ + 4⋅\thėta₁  + \thėta₂ ⎠
# ───────────────────────────────────────────────────────────────────────
#                                    6

# %% [markdown]
# * Potential energy $V$ comes from both the gravitational potential energy of the masses $mgy$

# %%
G1 = smp.Matrix([[0, -m_1*g, 0]])
G2 = smp.Matrix([[0, -m_2*g, 0]])
V1 = G1.dot(rC1)
V2 = G2.dot(rC2)
#V1 = m_1*l_g1*g*smp.sin(theta_1)
#V2 = m_2*g*(l_1*smp.sin(theta_1) + l_g2*smp.sin(theta_1+theta_2))
V = V1 + V2
V
# Out:
#   g⋅l⋅m⋅sin(\theta₁)       ⎛                 l⋅sin(\theta₂)⎞
# - ────────────────── - g⋅m⋅⎜l⋅sin(\theta₁) + ──────────────⎟
#           2                ⎝                       2       ⎠

# %% [markdown]
# Now we can look at the Lagrangian

# %%
#L_1 = L ; L_2 = L
L = T - V

L.simplify()
# Out:
#     ⎛
# l⋅m⋅⎝9⋅g⋅sin(\theta₁) + 3⋅g⋅sin(\theta₂) + 3⋅l⋅cos(\theta₁ - \theta₂)⋅\thėta₁
# ──────────────────────────────────────────────────────────────────────────────
#                                                         6
#
#                      2            2⎞
# ⋅\thėta₂ + 4⋅l⋅\thėta₁  + l⋅\thėta₂ ⎠
# ────────────────────────────────────

# %%
LE_Theta_1 = smp.diff(L, theta_1d)
LE_Theta_1.simplify()
# Out:
#  2
# l ⋅m⋅(3⋅cos(\theta₁ - \theta₂)⋅\thėta₂ + 8⋅\thėta₁)
# ───────────────────────────────────────────────────
#                          6

# %%
LE_Theta_2 = smp.diff(L, theta_2d)
LE_Theta_2.simplify()
# Out:
#  2
# l ⋅m⋅(3⋅cos(\theta₁ - \theta₂)⋅\thėta₁ + 2⋅\thėta₂)
# ───────────────────────────────────────────────────
#                          6

# %%
Torque1 = -beta_01*theta_1d-gamma_01*(theta_1-q1f)+smp.Rational(1,2)*g*l*m*smp.cos(theta_1) + g*l*m*smp.cos(theta_1)
#Torque1
Torque2 = -beta_12 *theta_2d-gamma_12*(theta_2-q2f)+smp.Rational(1,2)*g*l*m*smp.cos(theta_2)

# %% [markdown]
# Get Lagrange's equations
# $$\frac{d}{dt}\frac{\partial L}{\partial \dot{\theta_1}} - \frac{\partial L}{\partial \theta_1} = 0$$
# $$\frac{d}{dt}\frac{\partial L}{\partial \dot{\theta_2}} - \frac{\partial L}{\partial \theta_2} = 0$$

# %%
#LE1 = -smp.diff(L, theta_1) + smp.diff(smp.diff(L, theta_1d), t).simplify()
#LE2 = -smp.diff(L, theta_2) + smp.diff(smp.diff(L, theta_2d), t).simplify()
LE1 = -smp.diff(L, theta_1) + smp.diff(smp.diff(L, theta_1d), t).simplify()-Torque1+Torque2
LE2 = -smp.diff(L, theta_2) + smp.diff(smp.diff(L, theta_2d), t).simplify()-Torque2
#LE1, LE2

# %% [markdown]
# Solve Lagranges equations (this assumes that `LE1` and `LE2` are both equal to zero)
#
# * We solve these equations (which are **linear** in $\ddot{\theta_1}$ and $\ddot{\theta_2}$) for $\ddot{\theta_1}$ and $\ddot{\theta_2}$.

# %%
sols = smp.solve([LE1, LE2], (theta_1dd , theta_2dd ),
                simplify=False, rational=False)
sols
# Out:
# ⎧                                                                      5
# ⎪                                                   746496.0⋅g⋅l⋅m⋅cos (\theta
# ⎨\thëta₁: ───────────────────────────────────────────────────────────────────
# ⎪                   2      6                                 2      4
# ⎩         373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁
#
#
# ₁ - \theta₂)⋅cos(\theta₂)
# ───────────────────────────────────────────────────────────────────── - ──────
#                         2      2                                 2
# - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.
#
#                                                        4
#                                    1492992.0⋅g⋅l⋅m⋅cos (\theta₁ - \theta₂)⋅cos
# ──────────────────────────────────────────────────────────────────────────────
#    2      6                                 2      4
# 0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538
#
#
# (\theta₁)
# ──────────────────────────────────────────────────── + ───────────────────────
#        2      2                                 2               2      6
# 944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\thet
#
#                                      4
#                   248832.0⋅g⋅l⋅m⋅cos (\theta₁ - \theta₂)⋅cos(\theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#                            2      4                                 2      2
# a₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\
#
#
#
# ─────────────────────────────────── - ────────────────────────────────────────
#                                2               2      6
# theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1
#
#                      3
#  2654208.0⋅g⋅l⋅m⋅cos (\theta₁ - \theta₂)⋅cos(\theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#           2      4                                 2      2
# 990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂)
#
#
#                                                               5308416.0⋅g⋅l⋅m⋅
# ────────────────── + ─────────────────────────────────────────────────────────
#               2               2      6                                 2
#  - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos
#
#     2
# cos (\theta₁ - \theta₂)⋅cos(\theta₁)
# ──────────────────────────────────────────────────────────────────────────────
# 4                                 2      2                                 2
#  (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m
#
#                                                                 2
#                                              884736.0⋅g⋅l⋅m⋅cos (\theta₁ - \th
# ─ - ──────────────────────────────────────────────────────────────────────────
#              2      6                                 2      4
#    373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \thet
#
#
# eta₂)⋅cos(\theta₂)
# ────────────────────────────────────────────────────────────── + ─────────────
#                  2      2                                 2               2
# a₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅
#
#
#                             2359296.0⋅g⋅l⋅m⋅cos(\theta₁ - \theta₂)⋅cos(\theta₂
# ──────────────────────────────────────────────────────────────────────────────
#    6                                 2      4
# cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l
#
#
# )
# ───────────────────────────────────────────── - ──────────────────────────────
# 2      2                                 2               2      6
#  ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \t
#
#
#                        4718592.0⋅g⋅l⋅m⋅cos(\theta₁)
# ──────────────────────────────────────────────────────────────────────────────
#                     2      4                                 2      2
# heta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁
#
#
#
# ──────────────────────────── + ───────────────────────────────────────────────
#                         2               2      6
# - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.
#
#
#       786432.0⋅g⋅l⋅m⋅cos(\theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#    2      4                                 2      2
# 0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097
#
#                                                          2
#                                               373248.0⋅l ⋅m⋅sin(\theta₁ - \the
# ─────────── + ────────────────────────────────────────────────────────────────
#        2               2      6                                 2      4
# 152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\thet
#
#          5                           2
# ta₂)⋅cos (\theta₁ - \theta₂)⋅\thėta₁
# ──────────────────────────────────────────────────────────────────────── + ───
#                            2      2                                 2
# a₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   3732
#
#                                         2                             4
#                              248832.0⋅l ⋅m⋅sin(\theta₁ - \theta₂)⋅cos (\theta₁
# ──────────────────────────────────────────────────────────────────────────────
#       2      6                                 2      4
# 48.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3
#
#                     2
#  - \theta₂)⋅\thėta₂
# ─────────────────────────────────────────────────────── - ────────────────────
#           2      2                                 2               2      6
# 538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\t
#
#                         2                             3
#            1327104.0⋅l ⋅m⋅sin(\theta₁ - \theta₂)⋅cos (\theta₁ - \theta₂)⋅\thė
# ──────────────────────────────────────────────────────────────────────────────
#                               2      4                                 2
# heta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos
#
#     2
# ta₁                                                                      88473
# ────────────────────────────────────── - ─────────────────────────────────────
# 2                                 2               2      6
#  (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂)
#
#       2                             2                           2
# 6.0⋅l ⋅m⋅sin(\theta₁ - \theta₂)⋅cos (\theta₁ - \theta₂)⋅\thėta₂
# ──────────────────────────────────────────────────────────────────────────────
#              2      4                                 2      2
# - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \thet
#
#                                                                     2
#                                                         1179648.0⋅l ⋅m⋅sin(\th
# ───────────────────── + ──────────────────────────────────────────────────────
#                  2               2      6                                 2
# a₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅
#
#                                                2
# eta₁ - \theta₂)⋅cos(\theta₁ - \theta₂)⋅\thėta₁
# ──────────────────────────────────────────────────────────────────────────────
#    4                                 2      2
# cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l
#
#                                                               2
#                                                    786432.0⋅l ⋅m⋅sin(\theta₁ -
# ──── + ───────────────────────────────────────────────────────────────────────
# 2               2      6                                 2      4
#  ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \t
#
#                   2
#  \theta₂)⋅\thėta₂
# ───────────────────────────────────────────────────────────────── + ──────────
#                     2      2                                 2               2
# heta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l
#
#                                                            4
#                                    149299200.0⋅\theta₁⋅cos (\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#       6                                 2      4
# ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.
#
#
#
# ──────────────────────────────────────────────── - ───────────────────────────
#    2      2                                 2               2      6
# 0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ -
#
#                                           2
#                   530841600.0⋅\theta₁⋅cos (\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#                        2      4                                 2      2
#  \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\thet
#
#
#
# ─────────────────────────────── + ────────────────────────────────────────────
#                            2               2      6
# a₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 19906
#
#
#              471859200.0⋅\theta₁
# ──────────────────────────────────────────────────────────────────────────────
#       2      4                                 2      2
# 56.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2
#
#
#                                                               223948800.0⋅\the
# ────────────── - ─────────────────────────────────────────────────────────────
#           2               2      6                                 2      4
# 097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\t
#
#         5
# ta₂⋅cos (\theta₁ - \theta₂)
# ─────────────────────────────────────────────────────────────────────────── -
#                               2      2                                 2
# heta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   3
#
#                                                                      4
#                                              149299200.0⋅\theta₂⋅cos (\theta₁
# ──────────────────────────────────────────────────────────────────────────────
#          2      6                                 2      4
# 73248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂)
#
#
# - \theta₂)
# ────────────────────────────────────────────────────────── + ─────────────────
#              2      2                                 2               2      6
# + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos
#
#                                                     3
#                             796262400.0⋅\theta₂⋅cos (\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#                                  2      4                                 2
# (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅
#
#
#
# ───────────────────────────────────────── + ──────────────────────────────────
#    2                                 2               2      6
# cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta
#
#                                    2
#            530841600.0⋅\theta₂⋅cos (\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#                 2      4                                 2      2
# ₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \t
#
#
#                                                                          70778
# ──────────────────────── - ───────────────────────────────────────────────────
#                     2               2      6                                 2
# heta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l
#
#
# 8800.0⋅\theta₂⋅cos(\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#       4                                 2      2
# ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.
#
#
#                                                                    471859200.0
# ─────── - ────────────────────────────────────────────────────────────────────
#    2               2      6                                 2      4
# 0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ -
#
#
# ⋅\theta₂
# ──────────────────────────────────────────────────────────────────── - ───────
#                        2      2                                 2
#  \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0
#
#                                                       5
#                                       149299200.0⋅cos (\theta₁ - \theta₂)⋅\the
# ──────────────────────────────────────────────────────────────────────────────
#   2      6                                 2      4
# ⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 35389
#
#
# ̇ta₂
# ─────────────────────────────────────────────────── + ────────────────────────
#       2      2                                 2               2      6
# 44.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta
#
#                                             5
#                        234518634.953417⋅cos (\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#                           2      4                                 2      2
# ₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\t
#
#
#
# ────────────────────────────────── + ─────────────────────────────────────────
#                               2               2      6
# heta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 19
#
#                     4
#     223948800.0⋅cos (\theta₁ - \theta₂)⋅\thėta₁
# ──────────────────────────────────────────────────────────────────────────────
#          2      4                                 2      2
# 90656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂)
#
#
#                                                                  99532800.0⋅co
# ───────────────── - ──────────────────────────────────────────────────────────
#              2               2      6                                 2      4
# - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos
#
#    4
# s (\theta₁ - \theta₂)⋅\thėta₂
# ──────────────────────────────────────────────────────────────────────────────
#                                  2      2                                 2
# (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m
#
#                                                                        4
#                                                   78172878.3178055⋅cos (\theta
#  + ───────────────────────────────────────────────────────────────────────────
#             2      6                                 2      4
#   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta
#
#
# ₁ - \theta₂)
# ───────────────────────────────────────────────────────────── + ──────────────
#                 2      2                                 2               2
# ₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅c
#
#                                                3
#                                530841600.0⋅cos (\theta₁ - \theta₂)⋅\thėta₂
# ──────────────────────────────────────────────────────────────────────────────
#   6                                 2      4                                 2
# os (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l
#
#
#
# ──────────────────────────────────────────── - ───────────────────────────────
#       2                                 2               2      6
# ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \th
#
#                                      3
#                 833844035.389926⋅cos (\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#                    2      4                                 2      2
# eta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ -
#
#
#                                                                            796
# ─────────────────────────── - ────────────────────────────────────────────────
#                        2               2      6
#  \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0
#
#              2
# 262400.0⋅cos (\theta₁ - \theta₂)⋅\thėta₁
# ──────────────────────────────────────────────────────────────────────────────
#   2      4                                 2      2
# ⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 20971
#
#                                                                           2
#                                                           353894400.0⋅cos (\th
# ────────── + ─────────────────────────────────────────────────────────────────
#       2               2      6                                 2      4
# 52.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta
#
#
# eta₁ - \theta₂)⋅\thėta₂
# ─────────────────────────────────────────────────────────────────────── - ────
#                           2      2                                 2
# ₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   37324
#
#                                                                 2
#                                            277948011.796642⋅cos (\theta₁ - \th
# ──────────────────────────────────────────────────────────────────────────────
#      2      6                                 2      4
# 8.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 35
#
#
# eta₂)
# ────────────────────────────────────────────────────── - ─────────────────────
#          2      2                                 2               2      6
# 38944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\th
#
#
#                         471859200.0⋅cos(\theta₁ - \theta₂)⋅\thėta₂
# ──────────────────────────────────────────────────────────────────────────────
#                              2      4                                 2      2
# eta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos
#
#
#
# ───────────────────────────────────── + ──────────────────────────────────────
#                                  2               2      6
# (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) -
#
#
#          741194698.124378⋅cos(\theta₁ - \theta₂)
# ──────────────────────────────────────────────────────────────────────────────
#             2      4                                 2      2
#  1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta
#
#
#
# ──────────────────── + ───────────────────────────────────────────────────────
#                 2               2      6                                 2
# ₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅c
#
#
#   707788800.0⋅\thėta₁
# ──────────────────────────────────────────────────────────────────────────────
#   4                                 2      2                                 2
# os (\theta₁ - \theta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l
#
#
#                                                                314572800.0⋅\th
# ─── - ────────────────────────────────────────────────────────────────────────
#                2      6                                 2      4
# ⋅m   373248.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \th
#
#
# ėta₂
# ──────────────────────────────────────────────────────────────── + ───────────
#                    2      2                                 2               2
# eta₂) + 3538944.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m   373248.0⋅l ⋅
#
#
#                                                 247064899.374793
# ──────────────────────────────────────────────────────────────────────────────
#      6                                 2      4
# m⋅cos (\theta₁ - \theta₂) - 1990656.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) + 3538944.0
#
#
#                                                          54.0⋅g⋅l⋅m⋅cos(\theta
# ───────────────────────────────────────────────, \thëta₂: ───────────────────
#   2      2                                 2                   2      2
# ⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 2097152.0⋅l ⋅m            9.0⋅l ⋅m⋅cos (\theta
#
#
# ₁ - \theta₂)⋅cos(\theta₁)   9.0⋅g⋅l⋅m⋅cos(\theta₁ - \theta₂)⋅cos(\theta₂)
# ─────────────────────────── - ───────────────────────────────────────────── -
#                      2            2      2                            2
# ₁ - \theta₂) - 16.0⋅l ⋅m     9.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m   9.
#
#                                                    2
#         48.0⋅g⋅l⋅m⋅cos(\theta₂)              9.0⋅l ⋅m⋅sin(\theta₁ - \theta₂)⋅c
# ──────────────────────────────────────────── - ───────────────────────────────
#    2      2                            2                    2      2
# 0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m             9.0⋅l ⋅m⋅cos (\theta₁ -
#
#                               2          2                                 2
# os(\theta₁ - \theta₂)⋅\thėta₂     24.0⋅l ⋅m⋅sin(\theta₁ - \theta₂)⋅\thėta₁
# ──────────────────────────────── - ───────────────────────────────────────────
#                   2                   2      2                            2
#  \theta₂) - 16.0⋅l ⋅m            9.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m
#
#
#       5400.0⋅\theta₁⋅cos(\theta₁ - \theta₂)          5400.0⋅\theta₂⋅cos(\theta
# ─ - ──────────────────────────────────────────── + ───────────────────────────
#        2      2                            2          2      2
#   9.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m   9.0⋅l ⋅m⋅cos (\theta₁ - \thet
#
#
# ₁ - \theta₂)                     14400.0⋅\theta₂                     8100.0⋅co
# ───────────────── + ──────────────────────────────────────────── - ───────────
#             2          2      2                            2          2      2
# a₂) - 16.0⋅l ⋅m   9.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m   9.0⋅l ⋅m⋅cos
#
#
# s(\theta₁ - \theta₂)⋅\thėta₁         3600.0⋅cos(\theta₁ - \theta₂)⋅\thėta₂
# ───────────────────────────────── + ──────────────────────────────────────────
#                             2          2      2                            2
# (\theta₁ - \theta₂) - 16.0⋅l ⋅m   9.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m
#
#
#       2827.43338823081⋅cos(\theta₁ - \theta₂)                    9600.0⋅\thėt
# ── - ──────────────────────────────────────────── + ──────────────────────────
#         2      2                            2          2      2
#    9.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m   9.0⋅l ⋅m⋅cos (\theta₁ - \the
#
#                                                                ⎫
# a₂                                15079.644737231               ⎪
# ────────────────── - ────────────────────────────────────────────⎬
#              2          2      2                            2  ⎪
# ta₂) - 16.0⋅l ⋅m   9.0⋅l ⋅m⋅cos (\theta₁ - \theta₂) - 16.0⋅l ⋅m⎭

# %% [markdown]
# Now we have
#
# * $\frac{d^2 \theta_1}{dt^2} = ...$
# * $\frac{d^2 \theta_2}{dt^2} = ...$
#
# These are two second order ODEs! In python we can only solve systems of first order ODEs. Any system of second order ODEs can be converted as follows:
#
# 1. Define $z_1 = d\theta_1/dt$ and $z_2=d\theta_2/dt$
# 2. Then $dz_1/dt = d^2\theta_1/dt^2$ and $dz_2/dt = d^2\theta_2/dt^2$
#
# Now we get a system of 4 first order ODEs (as opposed to 2 second order ones)
#
# * $d z_1/dt = ...$
# * $d\theta_1/dt = z_1$
# * $d z_2/dt = ...$
# * $d\theta_2/dt = z_1$
#
# We need to convert the **symbolic** expressions above to numerical functions so we can use them in a numerical python solver. For this we use `smp.lambdify`

# %%
#dz1dt_f = smp.lambdify((t,g,m_1, m_2, I_1, I_2, l_1, l_g1, l_g2,theta_1,theta_2,theta_1d,theta_2d), sols[theta_1dd])
#dz2dt_f = smp.lambdify((t,g,m_1, m_2, I_1, I_2, l_1, l_g1, l_g2,theta_1,theta_2,theta_1d,theta_2d), sols[theta_2dd])
dz1dt_f = smp.lambdify((t,g,m,l,theta_1,theta_2,theta_1d,theta_2d), sols[theta_1dd])
dz2dt_f = smp.lambdify((t,g,m,l,theta_1,theta_2,theta_1d,theta_2d), sols[theta_2dd])
dthe1dt_f = smp.lambdify(theta_1d, theta_1d)
dthe2dt_f = smp.lambdify(theta_2d, theta_2d)

# %% [markdown]
# Now define $\vec{S} = (\theta_1, z_1, \theta_2, z_2)$. IF we're going to use an ODE solver in python, we need to write a function that takes in $\vec{S}$ and $t$ and returns $d\vec{S}/dt$. In other words, we need to define $d\vec{S}/dt (\vec{S}, t)$
#
# * Our system of ODEs can be fully specified using $d\vec{S}/dt$ and depends only on $\vec{S}$ and $t$

# %%
def dSdt(S, t, g,m,l):
    theta_1, z1, theta_2, z2 = S
    return [
        dthe1dt_f(z1),
        dz1dt_f(t,g,m,l,theta_1,theta_2,z1,z2),
        dthe2dt_f(z2),
        dz2dt_f(t,g,m,l,theta_1,theta_2,z1,z2),
    ]

# %% [markdown]
# Solve the system of ODEs using scipys `odeint` method

# %%
t = np.linspace(0, 15, 1001) # s
g = 9.81 #m/s^2
m = 1.0 # kg
l = 1.0 # m



y0=[smp.Rational(1,18)*math.pi, 0.0,smp.Rational(1,6)*math.pi, 0.0]
#y0=[0.1*math.pi, 0.0, 0.1*math.pi, 0.0]
#ans = odeint(dSdt, y0=[1, -1, -1, 1], t=t, args=(g, k, L0, m1, m2, m3, l1, l2))
ans = odeint(dSdt, y0, t=t, args=(g,m,l))
#ans.shape

# %%
the1 = ans.T[0]*smp.Rational(180/math.pi)
#the1 = ans.T[0]
the2 = ans.T[2]*smp.Rational(180/math.pi)

# %%
#plt.plot(t, the1,label= r'$\frac{d\theta_1}{dt} = \theta_2 $')
plt.plot(t, the1,'b--',label= 'theta1')
#plt.plot(t, the2)

# %%
plt.plot(t, the2)

# %%
LE1.simplify()
# Out:
#                                                         2
# -3.0⋅g⋅l⋅m⋅cos(\theta₁) + 0.5⋅g⋅l⋅m⋅cos(\theta₂) + 0.5⋅l ⋅m⋅sin(\theta₁ - \the
#
#             2        2                                                      2
# ta₂)⋅\thėta₂  + 0.5⋅l ⋅m⋅cos(\theta₁ - \theta₂)⋅\thëta₂ + 1.33333333333333⋅l
#
#
#  ⋅m⋅\thëta₁ + 300.0⋅\theta₁ - 300.0⋅\theta₂ + 450.0⋅\thėta₁ - 200.0⋅\thėta₂
#
#
#  + 157.07963267949
